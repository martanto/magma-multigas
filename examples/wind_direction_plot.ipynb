# %%
from magma_multigas import PlotWindDirection

# %%
csv = r"D:\Projects\magma-multigas\output\normalize\tangkuban_parahu\TANG_RTU_Data_6Hr.dat"

# %%
plot = PlotWindDirection(csv, volcano_name='Tangkuban Parahu', start_date='2024-05-17', end_date='2025-03-03', column_values=['Avg_CO2_H2S_ratio', 'Avg_H2S_SO2_ratio', 'Avg_CO2_S_tot_ratio'])
# Out:
# ✅ File already exists : D:\Projects\magma-multigas\examples\output\normalize\TANG_RTU_Data_6Hr.dat
# 📅 six_hours available from: 2024-03-09 00:30:00 to 2024-11-05 00:30:00

# %%
plot.show(interval=14, height=3, hspace=0.05)
# Out:
# 📷 Saved to : D:\Projects\magma-multigas\examples\output\figures\wind_direction\wind_direction_Tangkuban Parahu_2024-11-05-2024-11-05.png
# (<Figure size 1200x900 with 6 Axes>,
#  array([<Axes: ylabel='Avg_CO2_H2S_ratio'>,
#         <Axes: ylabel='Avg_H2S_SO2_ratio'>,
#         <Axes: ylabel='Avg_CO2_S_tot_ratio'>], dtype=object))
